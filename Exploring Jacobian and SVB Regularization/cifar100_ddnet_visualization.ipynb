# %% [markdown]
# # Visualizing Regularization of DDNet Trained on CIFAR100

# %% [markdown]
# In this notebook I visualize DDNet models trained on the CIFAR100 dataset using various regularization techniques. The CIFAR100 data is preprocessed by normalizing using mean [0.5071, 0.4865, 0.4409] and variance [0.2009, 0.1984, 0.2023]. The batch size is 100. The model optimizes using SGD with momentum p = 0.9, and standard cross-entropy loss. Model parameters are initialized using Glorot initialization (See Glorot & Bengio 2010), expect for SVB regularization which uses orthogonal initialization. Models are trained with no regularization, L2 regularization, SVB regularization and Jacobian regularization with a dropout rate of p_drop = 0.5. I also train a model with Jacobian Regularization without dropout. The L2 regularization coefficient and Jacobian regularization coefficient are the same as in Hoffman 2019: l2_lmbd = 0.0005 and lambda_jacobian_reg = 0.01. For SVB regularization I use the hyperparameters svb_freq=600 and svb_eps = 0.05. The learning rate starts at 0.1, and is reduced to 0.01 and 0.001 1/3 and 2/3s into training, respectively. The models are trained for 250 epochs.

# %% [markdown]
# ### Imports and Model Loading

# %%
import jupyter_black
import torch
from torchsummary import summary

from data_generators import data_loader_CIFAR100
from model_classes import DDNet
from plotting_tools import (
    plot_results,
    plot_reg_results,
    plot_decision_boundary,
    plot_and_print_img,
    generate_random_vectors,
    get_random_img,
    plot_fgsm,
    plot_multiple_fgsm,
    plot_pgd,
    plot_multiple_pgd,
)
from tools import ModelInfo

jupyter_black.load()
# Out:
#                 <script type="application/javascript" id="jupyter_black">
#                 (function() {
#                     if (window.IPython === undefined) {
#                         return
#                     }
#                     var msg = "WARNING: it looks like you might have loaded " +
#                         "jupyter_black in a non-lab notebook with " +
#                         "`is_lab=True`. Please double check, and if " +
#                         "loading with `%load_ext` please review the README!"
#                     console.log(msg)
#                     alert(msg)
#                 })()
#                 </script>

# %%
# Device configuration
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load MNIST data
train_loader, test_loader = data_loader_CIFAR100()

# Summary of model
summary_model = DDNet().to(device)
summary(summary_model, (3, 32, 32))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 30, 30]           1,792
#             Conv2d-2           [-1, 64, 28, 28]          36,928
#          MaxPool2d-3           [-1, 64, 14, 14]               0
#             Conv2d-4          [-1, 128, 12, 12]          73,856
#             Conv2d-5          [-1, 128, 10, 10]         147,584
#          MaxPool2d-6            [-1, 128, 5, 5]               0
#             Linear-7                  [-1, 256]         819,456
#            Dropout-8                  [-1, 256]               0
#             Linear-9                  [-1, 256]          65,792
#           Dropout-10                  [-1, 256]               0
#            Linear-11                   [-1, 10]           2,570
# ================================================================
# Total params: 1,147,978
# Trainable params: 1,147,978
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 1.19
# Params size (MB): 4.38
# Estimated Total Size (MB): 5.58
# ----------------------------------------------------------------

# %%
# Load models
dataset = "cifar100"
model_names = [
    "model_no_reg_0",
    "model_l2_0",
    "model_jacobi_0",
    "model_jacobi_no_dropout_0",
    "model_svb_0",
]
models = {name: ModelInfo(name, dataset) for name in model_names}

# %% [markdown]
# ### Plots of Accuracy Curves

# %%
for model_name in model_names:
    if model_name.startswith("model_no_reg"):
        plot_results(models, model_name, title=f"{model_name}")
    else:
        plot_reg_results(models, model_name, title=f"{model_name}")

# %% [markdown]
# ### Plots of Decision Boundaries

# %%
for model_name in model_names:
    image = get_random_img(test_loader)
    v1, v2 = generate_random_vectors(image)
    plot_and_print_img(
        image, models[f"{model_name}"].model, device, f"{model_name}", dataset
    )
    plot_decision_boundary(
        models[f"{model_name}"].model,
        image,
        v1,
        v2,
        device,
        resolution=100,
        dataset=dataset,
        title=f"{model_name}",
    )
# Out:
# Prediction with model_no_reg_0: airplane
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x00000250174E1E40>
# Traceback (most recent call last):
#   File "c:\ProgramData\Anaconda3\envs\bioai\Lib\site-packages\torch\utils\data\dataloader.py", line 1478, in __del__
#     self._shutdown_workers()
#   File "c:\ProgramData\Anaconda3\envs\bioai\Lib\site-packages\torch\utils\data\dataloader.py", line 1436, in _shutdown_workers
#     if self._persistent_workers or self._workers_status[worker_id]:
#                                    ^^^^^^^^^^^^^^^^^^^^
# AttributeError: '_MultiProcessingDataLoaderIter' object has no attribute '_workers_status'
# Prediction with model_no_reg_no_dropout_0: truck
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 7
#       3 v1, v2 = generate_random_vectors(image)
#       4 plot_and_print_img(
#       5     image, models[f"{model_name}"].model, device, f"{model_name}", dataset
#       6 )
# ----> 7 plot_decision_boundary(
#       8     models[f"{model_name}"].model,
#       9     image,
#      10     v1,
#      11     v2,
#      12     device,
#      13     resolution=100,
#      14     dataset="cifar10",
#      15     title=f"{model_name}",
#      16 )
#
# File c:\Users\aslak\Desktop\Jobb\Forskningsassistent\Biologisk inspirert kunstig intelligens\regNNs\Exploring Jacobian and SVB Regularization\plotting_tools.py:271, in plot_decision_boundary(model, img, v1, v2, device, resolution, zoom, dataset, title)
#     267         output = model(plane.view(-1, 1, 28, 28)).view(
#     268             resolution, resolution, -1
#     269         )
#     270     elif dataset == "cifar10":
# --> 271         output = model(plane.view(-1, 3, 32, 32)).view(
#     272             resolution, resolution, -1
#     273         )
#     275 probs = torch.nn.functional.softmax(output, dim=-1)
#     277 # Get the class with the highest probability
#
# File c:\ProgramData\Anaconda3\envs\bioai\Lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\aslak\Desktop\Jobb\Forskningsassistent\Biologisk inspirert kunstig intelligens\regNNs\Exploring Jacobian and SVB Regularization\model_classes.py:333, in DDNet.forward(self, x)
#     331 x = F.relu(x)
#     332 x = self.conv2(x)
# --> 333 x = self.pool(F.relu(x))
#     334 x = self.conv3(x)
#     335 x = F.relu(x)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Plots of Results of FGSM Attacks

# %%
for model_name in model_names:
    print(f"FGSM Attack Against Model: {model_name}")
    plot_fgsm(models[f"{model_name}"].model, model_name, device, test_loader, dataset)
# Out:
# FGSM Attack Against Model: model_no_reg_0
# FGSM Attack Against Model: model_no_reg_no_dropout_0
# FGSM Attack Against Model: model_l2_0
# FGSM Attack Against Model: model_l2_no_dropout_0
# FGSM Attack Against Model: model_jacobi_0
# FGSM Attack Against Model: model_jacobi_no_dropout_0
# FGSM Attack Against Model: model_svb_0
# FGSM Attack Against Model: model_svb_no_dropout_0
# FGSM Attack Against Model: model_jacobi_and_svb_0
# FGSM Attack Against Model: model_all_0
# FGSM Attack Against Model: model_jacobi_and_l2_0
# FGSM Attack Against Model: model_svb_and_l2_0

# %%
plot_multiple_fgsm(models, model_names, device, test_loader, dataset)

# %% [markdown]
# ### Plots of Results of PGD Attacks

# %%
for model_name in model_names:
    print(f"PGD Attack Against Model: {model_name}")
    plot_pgd(
        models[f"{model_name}"].model,
        model_name,
        device,
        test_loader,
        dataset,
    )
# Out:
# PGD Attack Against Model: model_no_reg_0
# PGD Attack Against Model: model_no_reg_no_dropout_0
# PGD Attack Against Model: model_l2_0
# PGD Attack Against Model: model_l2_no_dropout_0
# PGD Attack Against Model: model_jacobi_0
# PGD Attack Against Model: model_jacobi_no_dropout_0
# PGD Attack Against Model: model_svb_0
# PGD Attack Against Model: model_svb_no_dropout_0
# PGD Attack Against Model: model_jacobi_and_svb_0
# PGD Attack Against Model: model_all_0
# PGD Attack Against Model: model_jacobi_and_l2_0
# PGD Attack Against Model: model_svb_and_l2_0

# %%
plot_multiple_pgd(models, model_names, device, test_loader, dataset)
